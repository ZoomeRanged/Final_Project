# %%
import pandas as pd
import numpy as np
import json
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine

# %%
df = pd.read_json('D:\Final_Project\mongodata\companies.json')

# %%
for i in df.items():
    df.append([i[0], i[1]])
# Out:
# C:\Users\aldos\AppData\Local\Temp\ipykernel_2720\1442565683.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append([i[0], i[1]])

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dropna()

# %%
for i in range(df):
            companies_id = df[i]["_id"]["$oid"]
            name = df[i]["name"]
            permalink = df[i]["permalink"]
            crunchbase_url = df[i]["crunchbase_url"]
            homepage_url = df[i]["homepage_url"]
            blog_url = df[i]["blog_url"]
            blog_feed_url = df[i]["blog_feed_url"]
            twitter_username = df[i]["twitter_username"]
            category_code = df[i]["category_code"]
            number_of_employees = df[i]["number_of_employees"]
            founded_year = df[i]["founded_year"]
            founded_month = df[i]["founded_month"]
            founded_day = df[i]["founded_day"]
            deadpooled_year = df[i]["deadpooled_year"]
            tag_list = df[i]["tag_list"]
            email_address = df[i]["email_address"]
            phone_number = df[i]["phone_number"]
            description = df[i]["description"]
            created_at = str(df[i]["created_at"])
            updated_at = df[i]["updated_at"]
            overview = df[i]["overview"]
            total_money_raised = df[i]["total_money_raised"]
            offices = df[i]["offices"]
            for x in range(len(offices)):
                if(x == 0):
                    offices_description = offices[0]["description"]
                    offices_address1 = offices[0]["address1"]
                    offices_address2 = offices[0]["address2"]
                    offices_zip_code = offices[0]["zip_code"]
                    offices_city = offices[0]["city"]
                    offices_state_code = offices[0]["state_code"]
                    offices_country_code = offices[0]["country_code"]
                    offices_latitude = offices[0]["latitude"]
                    offices_longitude = offices[0]["longitude"]
            data_log = {
                "id" : companies_id,
                "name" : name,
                "permalink" : permalink,
                "crunchbase_url" : crunchbase_url,
                "homepage_url" : homepage_url,
                "blog_url" : blog_url,
                "blog_feed_url" : blog_feed_url,
                "twitter_username" : twitter_username,
                "category_code" : category_code,
                "number_of_employees" : number_of_employees,
                "founded_year" : founded_year,
                "founded_month" : founded_month,
                "founded_day" : founded_day,
                "deadpooled_year" : deadpooled_year,
                "tag_list" : tag_list,
                "email_address" : email_address,
                "phone_number" : phone_number,
                "description" : description,
                "created_at" : created_at,
                "updated_at" : updated_at,
                "overview" : overview,
                "total_money_raised" : total_money_raised,
                "offices_description" : offices_description,
                "offices_address1" : offices_address1,
                "offices_address2" : offices_address2,
                "offices_zipcode" : offices_zip_code,
                "offices_city" : offices_city,
                "offices_state_code" : offices_state_code,
                "offices_country_code" : offices_country_code,
                "offices_latitude" : offices_latitude,
                "offices_longitude" : offices_longitude
            }

            result_log.append(data_log)
        
df = pd.DataFrame.from_dict(result_log)
return df
#companies=pd.json_normalize(json.loads(df1.to_json(orient='records')))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for i in range(df):
#       2             companies_id = df[i]["_id"]["$oid"]
#       3             name = df[i]["name"]
#
# TypeError: 'DataFrame' object cannot be interpreted as an integer

# %%
df1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df1.head()
#
# NameError: name 'df1' is not defined

# %%
companies['offices'] = companies['offices'].astype(str)

# %%
companies['offices', 'description'] = list(map(lambda x: json.dumps(x), companies['offices']))

# %%
companies.drop(['partners','created_at.$date.$numberLong'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 companies.drop(['partners','created_at.$date.$numberLong'], axis=1, inplace=True)
#
# File d:\Final_Project\venv\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File d:\Final_Project\venv\lib\site-packages\pandas\core\frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
companies.head()
# Out:
#        name permalink                              crunchbase_url  \
# 0  Facebook  facebook  http://www.crunchbase.com/company/facebook
# 1  Facebook  facebook  http://www.crunchbase.com/company/facebook
# 2  Facebook  facebook  http://www.crunchbase.com/company/facebook
# 3  Facebook  facebook  http://www.crunchbase.com/company/facebook
# 4  Facebook  facebook  http://www.crunchbase.com/company/facebook
#
#           homepage_url                  blog_url  \
# 0  http://facebook.com  http://blog.facebook.com
# 1  http://facebook.com  http://blog.facebook.com
# 2  http://facebook.com  http://blog.facebook.com
# 3  http://facebook.com  http://blog.facebook.com
# 4  http://facebook.com  http://blog.facebook.com
#
#                        blog_feed_url twitter_username category_code  \
# 0  http://blog.facebook.com/atom.php         facebook        social
# 1  http://blog.facebook.com/atom.php         facebook        social
# ...

# %%
companies.explode('offices')
# Out:
#            name permalink                              crunchbase_url  \
# 0      Facebook  facebook  http://www.crunchbase.com/company/facebook
# 1      Facebook  facebook  http://www.crunchbase.com/company/facebook
# 2      Facebook  facebook  http://www.crunchbase.com/company/facebook
# 3      Facebook  facebook  http://www.crunchbase.com/company/facebook
# 4      Facebook  facebook  http://www.crunchbase.com/company/facebook
# ...         ...       ...                                         ...
# 77495   Intergy   intergy   http://www.crunchbase.com/company/intergy
# 77496   Intergy   intergy   http://www.crunchbase.com/company/intergy
# 77497   Intergy   intergy   http://www.crunchbase.com/company/intergy
# 77498   Intergy   intergy   http://www.crunchbase.com/company/intergy
# 77499   Intergy   intergy   http://www.crunchbase.com/company/intergy
#
#                      homepage_url                  blog_url  \
# 0             http://facebook.com  http://blog.facebook.com
# ...

# %%
engine = create_engine('postgresql+psycopg2://postgres:admin@localhost:5432/postgres')
companies.to_sql('companies', engine, if_exists='replace')
# Out:
# 500
